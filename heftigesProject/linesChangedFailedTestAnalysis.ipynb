# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

constante = 'C:/Users/stoc_ad/Desktop/travistorrent_11_1_2017.csv'

df = pd.read_csv(constante, sep = ',')

listeTestsFailed = df['tr_log_num_tests_failed']
listeLinesChanged = df['git_diff_test_churn']

listeTestsFailedFiltered = []
listeLiesChangedFiltered = []

for e in range(len(a[0:500000])):
    if str(listeTestsFailed[e]) != "nan":
        if not((listeTestsFailed[e] == 0) and (listeLinesChanged[e] == 0)):
            listeTestsFailedFiltered += [listeTestsFailed[e]]
            listeLiesChangedFiltered += [listeLinesChanged[e]]

plt.plot(listeLiesChangedFiltered, listeTestsFailedFiltered, 'ro')
plt.axis([-350, 7000, -50, 1000])
plt.xlabel('Number of lines of test code changed')
plt.ylabel('Tests failed')
plt.show()
# Out:
# C:\Users\stoc_ad\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (3,6,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
listeTestsFailedFiltered = []
listeLiesChangedFiltered = []

for e in range(len(a[0:500000])):
    if str(listeTestsFailed[e]) != "nan":
        if not((listeTestsFailed[e] == 0) and (listeLinesChanged[e] == 0)):
            listeTestsFailedFiltered += [listeTestsFailed[e]]
            listeLiesChangedFiltered += [listeLinesChanged[e]]

plt.plot(listeLiesChangedFiltered, listeTestsFailedFiltered, 'ro')
plt.axis([-350, 7000, -50, 1000])
plt.xlabel('Number of lines of test code changed')
plt.ylabel('Tests failed')
plt.show()
